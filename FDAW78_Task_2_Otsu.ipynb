# %% [markdown]
# **TASK 2**
#
# **NEPTUNE ID : FDAW78**
#
# **NAME : INDRA AWAL PRIYANTO**

# %%
#Download dataset from: https://drive.google.com/file/d/1nmobeX9BQMLGLnI4Fn_dPlCqqUwjYBLX/view?usp=sharing
# !gdown --id 1nmobeX9BQMLGLnI4Fn_dPlCqqUwjYBLX
# !unzip 1_prewitt.zip -d ./dataset
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1nmobeX9BQMLGLnI4Fn_dPlCqqUwjYBLX
# To: /content/1_prewitt.zip
# 100% 380k/380k [00:00<00:00, 111MB/s]
# Archive:  1_prewitt.zip
#   inflating: ./dataset/circlegrey.png
#   inflating: ./dataset/circlegrey.tif
#  extracting: ./dataset/julia.png
#   inflating: ./dataset/julia.tif
#   inflating: ./dataset/motor.png
#   inflating: ./dataset/motor.tif

# %%
import cv2
import numpy as np
import glob
import matplotlib.pyplot as plt
import os
import skimage.exposure
import skimage.io
import skimage.color
import skimage.filters
from PIL import Image
from matplotlib.pyplot import imshow, show, subplot, figure, gray, title, axis

# %%
file = '/content/dataset/*.png' 
glob.glob(file)
images = [cv2.imread(image) for image in glob.glob(file)]

fig=plt.figure(figsize=(10, 10))
rows, cols = 1, 3
# Display all of images
for j in range(0, len(images)):
  fig.add_subplot(rows, cols, j+1)
  plt.imshow(images[j])
plt.show()

# %%
im = cv2.imread('/content/dataset/motor.png', 0)
otsu_threshold, image_result = cv2.threshold(
    im, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU,
)

# blur = cv2.GaussianBlur(im,(5,5),0)
# ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

gray()

fig = plt.figure(figsize=(10, 10))
fig.add_subplot(2, 2, 1)
imshow(im)
axis('off')
title('Original')

fig.add_subplot(2, 2, 2)
imshow(image_result)
axis('off')
title('Otsu Thereshold')

# fig.add_subplot(1, 3, 3)
# imshow(th3)
# axis('off')
# title('Otsu Thereshold + Gaussian')

show()

print("Thereshold Value: ", otsu_threshold)
# Out:
# Thereshold Value:  107.0

# %%
im2 = cv2.imread('/content/dataset/circlegrey.png', 0)
otsu_threshold2, image_result2 = cv2.threshold(
    im2, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU,
)

# blur = cv2.GaussianBlur(im,(5,5),0)
# ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

gray()

fig = plt.figure(figsize=(10, 10))
fig.add_subplot(2, 2, 1)
imshow(im2)
axis('off')
title('Original')

fig.add_subplot(2, 2, 2)
imshow(image_result2)
axis('off')
title('Otsu Thereshold')

# fig.add_subplot(1, 3, 3)
# imshow(th3)
# axis('off')
# title('Otsu Thereshold + Gaussian')

show()

print("Thereshold Value: ", otsu_threshold2)
# Out:
# Thereshold Value:  131.0

# %%
im3 = cv2.imread('/content/dataset/julia.png', 0)
otsu_threshold3, image_result3 = cv2.threshold(
    im3, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU,
)

# blur = cv2.GaussianBlur(im,(5,5),0)
# ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

gray()

fig = plt.figure(figsize=(10, 10))
fig.add_subplot(2, 2, 1)
imshow(im3)
axis('off')
title('Original')

fig.add_subplot(2, 2, 2)
imshow(image_result3)
axis('off')
title('Otsu Thereshold')

# fig.add_subplot(1, 3, 3)
# imshow(th3)
# axis('off')
# title('Otsu Thereshold + Gaussian')

show()

print("Thereshold Value: ", otsu_threshold3)
# Out:
# Thereshold Value:  149.0
