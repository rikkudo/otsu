# %% [markdown]
# **TASK 2**
#
# **NEPTUNE ID : FDAW78**
#
# **NAME : INDRA AWAL PRIYANTO**

# %%
#Download dataset from: https://drive.google.com/file/d/1v6OMwTDsRJR3L5CuDk2wVWh1U3QZ23_5/view?usp=sharing
# !gdown --id 1v6OMwTDsRJR3L5CuDk2wVWh1U3QZ23_5
# !unzip 2_otsu.zip -d ./dataset
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1v6OMwTDsRJR3L5CuDk2wVWh1U3QZ23_5
# To: /content/2_otsu.zip
# 100% 432k/432k [00:00<00:00, 102MB/s]
# Archive:  2_otsu.zip
#   inflating: ./dataset/aluminium.png
#   inflating: ./dataset/aluminium.tif
#  extracting: ./dataset/finger.png
#   inflating: ./dataset/finger.tif
#  extracting: ./dataset/julia.png
#   inflating: ./dataset/julia.tif
#   inflating: ./dataset/phobos.png
#   inflating: ./dataset/phobos.tif

# %%
import cv2
import numpy as np
import glob
import matplotlib.pyplot as plt
import os
import skimage.exposure
import skimage.io
import skimage.color
import skimage.filters
from PIL import Image
from matplotlib.pyplot import imshow, show, subplot, figure, gray, title, axis

# %%
file = '/content/dataset/*.png' 
glob.glob(file)
images = [cv2.imread(image) for image in glob.glob(file)]

fig=plt.figure(figsize=(10, 10))
rows, cols = 1, 4
# Display all of images
for j in range(0, len(images)):
  fig.add_subplot(rows, cols, j+1)
  plt.imshow(images[j])
plt.show()

# %%
im = cv2.imread('/content/dataset/aluminium.png', 0)
otsu_threshold, image_result = cv2.threshold(
    im, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU,
)

# blur = cv2.GaussianBlur(im,(5,5),0)
# ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

gray()

fig = plt.figure(figsize=(10, 10))
fig.add_subplot(2, 2, 1)
imshow(im)
axis('off')
title('Original')

fig.add_subplot(2, 2, 2)
imshow(image_result)
axis('off')
title('Otsu Thereshold')

# fig.add_subplot(1, 3, 3)
# imshow(th3)
# axis('off')
# title('Otsu Thereshold + Gaussian')

show()

print("Thereshold Value: ", otsu_threshold)
# Out:
# Thereshold Value:  103.0

# %%
im2 = cv2.imread('/content/dataset/finger.png', 0)
otsu_threshold2, image_result2 = cv2.threshold(
    im2, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU,
)

# blur = cv2.GaussianBlur(im,(5,5),0)
# ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

gray()

fig = plt.figure(figsize=(10, 10))
fig.add_subplot(2, 2, 1)
imshow(im2)
axis('off')
title('Original')

fig.add_subplot(2, 2, 2)
imshow(image_result2)
axis('off')
title('Otsu Thereshold')

# fig.add_subplot(1, 3, 3)
# imshow(th3)
# axis('off')
# title('Otsu Thereshold + Gaussian')

show()

print("Thereshold Value: ", otsu_threshold2)
# Out:
# Thereshold Value:  158.0

# %%
im3 = cv2.imread('/content/dataset/julia.png', 0)
otsu_threshold3, image_result3 = cv2.threshold(
    im3, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU,
)

# blur = cv2.GaussianBlur(im,(5,5),0)
# ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

gray()

fig = plt.figure(figsize=(10, 10))
fig.add_subplot(2, 2, 1)
imshow(im3)
axis('off')
title('Original')

fig.add_subplot(2, 2, 2)
imshow(image_result3)
axis('off')
title('Otsu Thereshold')

# fig.add_subplot(1, 3, 3)
# imshow(th3)
# axis('off')
# title('Otsu Thereshold + Gaussian')

show()

print("Thereshold Value: ", otsu_threshold3)
# Out:
# Thereshold Value:  149.0

# %%
im4 = cv2.imread('/content/dataset/phobos.png', 0)
otsu_threshold4, image_result4 = cv2.threshold(
    im4, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU,
)

# blur = cv2.GaussianBlur(im,(5,5),0)
# ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

gray()

fig = plt.figure(figsize=(10, 10))
fig.add_subplot(2, 2, 1)
imshow(im4)
axis('off')
title('Original')

fig.add_subplot(2, 2, 2)
imshow(image_result4)
axis('off')
title('Otsu Thereshold')

# fig.add_subplot(1, 3, 3)
# imshow(th3)
# axis('off')
# title('Otsu Thereshold + Gaussian')

show()

print("Thereshold Value: ", otsu_threshold4)
# Out:
# Thereshold Value:  62.0
